# %% [markdown]
# # Pivoting / Reshaping - Exercises

# %% [markdown]
# # Preparations

# %%
import pandas as pd

pd.set_option("display.max_columns", 500)

# %% [markdown]
# # Exercise
#
# 1. Load the first sheet of the Excel file "wdi_reduced.xlsx" into a pandas DataFrame (see [here](https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html) for help with `pandas.read_excel()`)
# 2. Select only the columns *countrycode*, *year*, and *NY_GDP_MKTP_CD*.
# 3. Select only the years after 2010.
# 4. Reshape to wide format. (One row per *countrycode*)
# 5. Generate a new column "large_value_in_2011" indicating whether a country had a *NY_GDP_MKTP_CD* above the 2011-median.
# 6. Reshape to long format. (One row per *countrycode* and *year*).

# %% [markdown]
# # 1. Load the first sheet of the Excel file "wdi_timeseries.xlsx" into a pandas DataFrame (see [here](https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html) for help with `pandas.read_excel()`)

# %%
df = pd.read_excel("../../data/raw/wdi_reduced.xlsx", sheet_name="wdi")
df.head(3)
# Out:
#   countrycode countryname                     region  year  NY_GDP_MKTP_CD  \
# 0         ABW       Aruba  Latin America & Caribbean  2007    2.623726e+09
# 1         ABW       Aruba  Latin America & Caribbean  2011    2.584464e+09
# 2         ABW       Aruba  Latin America & Caribbean  1992             NaN
#
#    NY_GDP_MKTP_KD_ZG  SP_POP_TOTL
# 0          -3.654626     101220.0
# 1                NaN     102053.0
# 2                NaN      68235.0

# %% [markdown]
# # 2. Select only the columns *countrycode*, *year*, and *NY_GDP_MKTP_CD*.

# %%
df = df[["countrycode", "year", "NY_GDP_MKTP_CD"]]
df.head(3)
# Out:
#   countrycode  year  NY_GDP_MKTP_CD
# 0         ABW  2007    2.623726e+09
# 1         ABW  2011    2.584464e+09
# 2         ABW  1992             NaN

# %% [markdown]
# # 3. Select only the years after 2010.

# %%
df = df[df["year"] > 2010]
df.head(3)
# Out:
#    countrycode  year  NY_GDP_MKTP_CD
# 1          ABW  2011    2.584464e+09
# 27         ABW  2012             NaN
# 32         ABW  2016             NaN

# %% [markdown]
# # 4. Reshape to wide format. (One row per *countrycode*)

# %%
df_wide = df.pivot_table(index="countrycode", columns="year")
df_wide.head(3)
# Out:
#             NY_GDP_MKTP_CD                                            \
# year                  2011          2012          2013          2014
# countrycode
# ABW           2.584464e+09           NaN           NaN           NaN
# AFG           1.793024e+10  2.053654e+10  2.004633e+10  2.005019e+10
# AGO           1.041159e+11  1.153984e+11  1.249121e+11  1.267769e+11
#
#
# year                 2015          2016
# countrycode
# ABW                   NaN           NaN
# AFG          1.970299e+10  1.946902e+10
# AGO          1.029622e+11  8.963316e+10

# %%
def simplify_df(df, flatten_columns=True, reset_index=True):
    # Create a copy to avoid modifying the original
    # Note: In pandas 3.0+, Copy-on-Write makes this copy mostly for clarit
    df = df.copy()

    def join_if_more_than_one(x):
        if len(x) > 1:
            return "_".join(x)
        else:
            return x[0]

    if flatten_columns and (isinstance(df.columns, pd.MultiIndex)):
        df.columns = [
            join_if_more_than_one(list(filter(None, item)))
            for item in [list(str(i) for i in t) for t in df.columns.to_flat_index()]
        ]
    if reset_index:
        df = df.reset_index()
    return df

# %%
df_wide = simplify_df(df_wide)
df_wide
# Out:
#     countrycode  NY_GDP_MKTP_CD_2011  NY_GDP_MKTP_CD_2012  \
# 0           ABW         2.584464e+09                  NaN
# 1           AFG         1.793024e+10         2.053654e+10
# 2           AGO         1.041159e+11         1.153984e+11
# 3           ALB         1.289087e+10         1.231978e+10
# 4           AND         3.427023e+09         3.146152e+09
# ..          ...                  ...                  ...
# 199         XKX         6.649291e+09         6.473725e+09
# 200         YEM         3.272642e+10         3.540134e+10
# 201         ZAF         4.164189e+11         3.963278e+11
# 202         ZMB         2.346010e+10         2.550337e+10
# 203         ZWE         1.207173e+10         1.405838e+10
#
#      NY_GDP_MKTP_CD_2013  NY_GDP_MKTP_CD_2014  NY_GDP_MKTP_CD_2015  \
# 0                    NaN                  NaN                  NaN
# 1           2.004633e+10         2.005019e+10         1.970299e+10
# 2           1.249121e+11         1.267769e+11         1.029622e+11
# 3           1.278103e+10         1.321986e+10         1.139037e+10
# 4           3.248925e+09                  NaN                  NaN
# ..                   ...                  ...                  ...
# 199         7.072092e+09         7.386891e+09         6.440501e+09
# 200         4.041523e+10         4.322858e+10         3.773392e+10
# 201         3.666239e+11         3.508506e+11         3.174066e+11
# 202         2.804546e+10         2.715063e+10         2.115439e+10
# 203         1.522353e+10         1.583407e+10         1.607238e+10
#
#      NY_GDP_MKTP_CD_2016
# 0                    NaN
# 1           1.946902e+10
# 2           8.963316e+10
# 3           1.192689e+10
# 4                    NaN
# ..                   ...
# 199         6.649889e+09
# 200         2.731761e+10
# 201         2.948406e+11
# 202         1.955109e+10
# 203         1.628921e+10
#
# [204 rows x 7 columns]

# %% [markdown]
# # 5. Generate a new column "large_value_in_2011" indicating whether a country had a *NY_GDP_MKTP_CD* above the 2011-median.

# %%
df_wide["large_value_in_2011"] = (
    df_wide["NY_GDP_MKTP_CD_2011"] > df_wide["NY_GDP_MKTP_CD_2011"].median()
)
df_wide.head(3)
# Out:
#   countrycode  NY_GDP_MKTP_CD_2011  NY_GDP_MKTP_CD_2012  NY_GDP_MKTP_CD_2013  \
# 0         ABW         2.584464e+09                  NaN                  NaN
# 1         AFG         1.793024e+10         2.053654e+10         2.004633e+10
# 2         AGO         1.041159e+11         1.153984e+11         1.249121e+11
#
#    NY_GDP_MKTP_CD_2014  NY_GDP_MKTP_CD_2015  NY_GDP_MKTP_CD_2016  \
# 0                  NaN                  NaN                  NaN
# 1         2.005019e+10         1.970299e+10         1.946902e+10
# 2         1.267769e+11         1.029622e+11         8.963316e+10
#
#    large_value_in_2011
# 0                False
# 1                False
# 2                 True

# %% [markdown]
# # 6. Reshape to long format. (One row per *countrycode* and *year*).

# %%
df_long = df_wide.melt(id_vars=["countrycode", "large_value_in_2011"], var_name="year")
df_long.head(3)
# Out:
#   countrycode  large_value_in_2011                 year         value
# 0         ABW                False  NY_GDP_MKTP_CD_2011  2.584464e+09
# 1         AFG                False  NY_GDP_MKTP_CD_2011  1.793024e+10
# 2         AGO                 True  NY_GDP_MKTP_CD_2011  1.041159e+11

# %%
df_long["year"] = df_long["year"].str[-4:].astype("int")
df_long.head(3)
# Out:
#   countrycode  large_value_in_2011  year         value
# 0         ABW                False  2011  2.584464e+09
# 1         AFG                False  2011  1.793024e+10
# 2         AGO                 True  2011  1.041159e+11
